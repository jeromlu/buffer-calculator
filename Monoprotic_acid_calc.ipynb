# %% [markdown]
# # Monoprotic acid
#
# Links:
# [Wikipedia](https://en.wikipedia.org/wiki/Acid_dissociation_constant)
# [Chem buddy](https://www.chembuddy.com/?left=pH-calculation&right=toc)
# [Dissociation constants 1](https://chem.libretexts.org/Bookshelves/Ancillary_Materials/Reference/Reference_Tables/Equilibrium_Constants/E1%3A_Acid_Dissociation_Constants_at_25C)
# [aqion pH masurements](https://www.aqion.de/site/191)
# [aqion pH calculator](http://www.aqion.onl/)
#
# Equations:
# HA -> A- + H+
#
# Equilibrium constant
# $K_a = \frac{[A^-][H^+]}{[HA]}$
#
# Mass balance:
# $C_a = [HA] + [A^-]$
#
# Charge balance (we have neutral solution):
# $[OH^-] + [A^-] = [H^+]$
#
# Full solution to above system:
# $[H^+]^3-K_a [H^+]^2 - (C_aK_a+K_w)[H^+]-K_aK_w=0$
#
# Strong acid approximation:
# $[A^-] \approx C_a$
# $[H^+] = \frac{C_a}{2}(1\pm\sqrt{1-\frac{4K_w}{C_a^2}})$
# Even stronger (less accurate) approximation:
# $[H^+] \approx C_a$
#
#
# ### Data:
# Water dissociation constant:
# $K_w=10^{-14}$ (at 25 C)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt5

# %% [markdown]
# ## Solvers

# %%
def bisect(f, a, b, eps=1e-6, maxiter=15, m = 1, verbose = False):
    if f(a)*f(b) >= 0:
        print("Error func")
        return
    i = 0
    while (abs(a-b) > eps and (i < maxiter)):
        zero = (b + a) / 2
        if f(zero)*f(b) < 0:
            a = zero
        else:
            b = zero
        i += 1
    return zero
    
def newton_iteration(f, fder, x0, eps=1e-15, maxiter=1000, m = 1, verbose = False):
    """Find a root of $f(x) = 0$ via Newton's iteration starting from x0.
    I've added the modified version.
    
    Parameters
    ----------
    f : callable
        The function to find a root of.
    fder : callable
        The derivative of `f`.
    x0 : float
        Initial value for the Newton's iteration.
    eps : float
        The target accuracy. 
        The iteration stops when the distance between successive iterates is below `eps`.
        Default is 1e-5.
    maxiter : int
        The maximum number of iterations (default is 1000.)
        Iterations terminate if the number of iterations exceeds `maxiter`.
        This parameter is only needed to avoid infinite loops if iterations wander off.
        
    Returns
    -------
    x : float
        The estimate for the root.
    niter : int
        The number of iterations.
    """
    x_prev = x0+2*eps
    x_new = x0
    i=0
    while(abs(x_prev - x_new) > eps and i < maxiter):
        x_prev = x_new
        x_new = x_prev - m * (f(x_prev)/fder(x_prev))
        #x_prev = x
        if i < 100 and verbose:
            print("i: ",i, "old: ", x_prev, "new: ", x_new)
        i += 1
        
    return x_new, i

# %%
# initial data
# acid molar concentration
HCl_data = {
    "c_a" : 0.01, # mol/L
    "K_a" : [7.9e5]
}
Acetic_data = {
    "c_a" : 0.01,
    "K_a" : [1.75e-5],
    "pK_a" : [4.756]
} 
hydrocyanic_data = {
    "c_a" : 0.1,
    "pK_a" : [9.31]
}

# %%
def calc_pH_acid(c_a, K_a, K_w = 10e-14, verbose = True, plot= False):
    
    solutions = []
    
    # strong approximations
    strong_approx = c_a/2*(1+np.sqrt(1-4*K_w/c_a**2))
    strong_strong_approx = c_a
    
    # weak approximations
    weak_approx = (-K_a + np.sqrt(K_a**2 + 4 * K_a * c_a)) / 2
    weak_weak_approx = K_a / 2 + np.sqrt(K_a * c_a)
    weak_weak_weak_approx = np.sqrt(K_a * c_a)
    
    # defining equation and derivative
    def equation(x):
        return x**3 + K_a * x**2 - (c_a * K_a) * x - K_a * K_w
    def equation_der(x):
        return 3*x**2 + 2 * K_a * x - (c_a * K_a)
    
    #plotting data
    if plot:
        x = np.linspace(-0.001, 0.0561, 100)
        y = x**3+K_a*x**2-(c_a*K_a)*x-K_a*K_w
        fig, ax = plt.subplots()
        ax.plot(x, y)
        ax.axhline(0, color = "k")
        
    exact = bisect(equation, 1e-10, 0.2)
    better = newton_iteration(equation, equation_der, exact)
    solutions.append(better[0])
    solutions.append(strong_approx)
    solutions.append(strong_strong_approx)
    solutions.append(weak_approx)
    solutions.append(weak_weak_approx)
    solutions.append(weak_weak_weak_approx)
    solutions = -np.log10(np.array(solutions))
    
    if verbose:
        txt = "{:7.4f} {:7.4f} {:7.4f} {:7.4f} {:7.4f} {:7.4f}"
        print(txt.format(*solutions))
    return -np.log10(exact), -np.log10(better[0])
c_a = HCl_data["c_a"]
K_a = HCl_data["K_a"][0]
_ = (calc_pH_acid(c_a, K_a))
c_a = Acetic_data["c_a"]
K_a = 10**(-Acetic_data["pK_a"][0])
_ = (calc_pH_acid(c_a, K_a, plot=False))
c_a = hydrocyanic_data["c_a"]
K_a = 10**(-hydrocyanic_data["pK_a"][0])
_ = (calc_pH_acid(c_a, K_a))
# Out:
#  2.0000  2.0000  2.0000  2.0000 -5.5967 -1.9488
#  3.3871  2.0000  2.0000  3.3871  3.3690  3.3780
#  5.1550  1.0000  1.0000  5.1550  5.1550  5.1550

# %%
# molarities are in mol/L
# Input data
molarities_dict = {
    "Acetic acid" : 0.01,
    #"Citric acid" : 0.1,
    #"Phosphoric acid" : 0.003,
}

# REquired data.
pKa_dict = {
    "Acetic acid" : np.array([4.756]),
    "Citric acid" : np.array([3.128, 4.761, 6.396]),
    "Glycine" : np.array([2.35]),
    "Hydrocloric acid" : np.array([-4]),
    "Hydorcyanic acid" : np.array([9.31]),
    "Nitric acid" : np.array([-1]),
    "Phosphoric acid" : np.array([2.147, 7.207, 12.346]),
    "Succinic acid" : np.array([4.2, 5.6]),
    "TRIS" : np.array([])
}

# charges of conjugate (bases acid -> conjuget_base + H^+ ---- HA -> A^- + H^+)
charges_dict = {
    "OH" : np.array([-1]),
    "H" : np.array([1]),
    "Acetic acid" : np.array([-1]),
    "Citric acid" : np.array([-1, -2, -3]),
    "Glycine" : np.array([-1]),
    "Hydrocloric acid" : np.array([-1]),
    "Hydorcyanic acid" : np.array([-1]),
    "Nitric acid" : np.array([-1]),
    "Phosphoric acid" : np.array([-1, -2, -2]),
    "Succinic acid" : np.array([-1, -2]),
}

def ion_strength(ion_molarities_dict, charge_dict, c_Na = 0.0, c_Cl = 0.0):
    ion_strength = 0
    for species in ion_molarities_dict:
        ion_strength += (charge_dict[species]**2 * ion_molarities_dict[species]).sum()
        
    return (ion_strength + c_Na + c_Cl) / 2.0

def electro_neutrality_error(ion_molarities_dict, charge_dict, c_Na = 0.0, c_Cl = 0.0):
    error = 0
    for species in ion_molarities_dict:
        #print("Electro neu calc: {} {} {}".format(species, charge_dict[species], ion_molarities_dict[species]))
        error += (charge_dict[species] * ion_molarities_dict[species]).sum()
        
    return error + c_Na - c_Cl

def ion_strength_error(ion_strength_guess, ion_molarities_dict, charge_dict, c_Na = 0.0, c_Cl = 0.0):
    return ion_strength_guess - ion_strength(ion_molarities_dict, charge_dict, c_Na = 0.0, c_Cl = 0.0)

def calculate_molarities(molarities_dict, pKa_dict, charge_dict, pH, ion_strength, correct_for_IS = True):
    """Calculates molarites of all charged species (ions) in water solution at given pH and ion_stregth."""
    c_H = 10**(-pH)
    K_w = 10**(-14)
    c_OH = K_w / c_H
    ion_molarities = {
        "H" : np.array([c_H]),
        "OH" : np.array([c_OH]),
    }
    for species in molarities_dict:
        ion_molarities[species] = np.zeros(len(pKa_dict[species]))
        denom = 1
        term = 1
        for charge, pK_a in zip(charge_dict[species], pKa_dict[species]):
            pK_a_eff = pK_a
            if correct_for_IS:
                pK_a_eff += 2 * (charge) * (0.5114 * np.sqrt(ion_strength) / (1 + np.sqrt(ion_strength)) - 0.1 * ion_strength)
            term *= 10**(-pK_a_eff) / c_H
            denom += term
        molarity = molarities_dict[species] / denom
        for i, pK_a in enumerate(pKa_dict[species]):
            pK_a_eff = pK_a
            if correct_for_IS:
                pK_a_eff += 2 * (charge) * (0.5114 * np.sqrt(ion_strength) / (1 + np.sqrt(ion_strength)) - 0.1 * ion_strength)
            molarity *= 10**(-pK_a_eff) / c_H
            ion_molarities[species][i] = molarity
    return ion_molarities

c_Na = 0.30
c_Cl = 0.0

print(ion_strength(molarities_dict, charges_dict, c_Na, c_Cl))
print(electro_neutrality_error(molarities_dict, charges_dict, c_Na, c_Cl))

print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 3, 2, correct_for_IS=False))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 3, 2))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 5, 2, correct_for_IS=False))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 5, 2))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 6, 2, correct_for_IS=False))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 6, 2))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 7, 2, correct_for_IS=False))
print(calculate_molarities(molarities_dict, pKa_dict, charges_dict, 7, 2))
# Out:
# 0.155
# 0.29
# {'H': array([0.001]), 'OH': array([1.e-11]), 'Acetic acid': array([0.00017236])}
# {'H': array([0.001]), 'OH': array([1.e-11]), 'Acetic acid': array([0.00026993])}
# {'H': array([1.e-05]), 'OH': array([1.e-09]), 'Acetic acid': array([0.00636876])}
# {'H': array([1.e-05]), 'OH': array([1.e-09]), 'Acetic acid': array([0.00735045])}
# {'H': array([1.e-06]), 'OH': array([1.e-08]), 'Acetic acid': array([0.00946059])}
# {'H': array([1.e-06]), 'OH': array([1.e-08]), 'Acetic acid': array([0.00965208])}
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.00994331])}
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.00996408])}

# %%
print("##### Benchmark pH")
c_a = Acetic_data["c_a"]
print("C_a: {} M".format(c_a))
K_a = 10**(-Acetic_data["pK_a"][0])
_ = (calc_pH_acid(c_a, K_a, plot=False))
print("end\n")

c_Na = 0.0
c_Cl = 0.0
print(molarities_dict, "\n")

ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, 2.62, 0.0572333372, correct_for_IS=True)
print(ion_molarities_dict)
print(electro_neutrality_error(ion_molarities_dict, charges_dict, c_Na, c_Cl))
print(ion_strength(ion_molarities_dict, charges_dict), "\n")

ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, 4, 2, correct_for_IS=False)
print(ion_molarities_dict)
print(electro_neutrality_error(ion_molarities_dict, charges_dict, c_Na, c_Cl))

ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, 3.38, 2, correct_for_IS=False)
print(ion_molarities_dict)
print(electro_neutrality_error(ion_molarities_dict, charges_dict, c_Na, c_Cl),"\n")

ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, 3.3871, 2, correct_for_IS=False)
print(ion_molarities_dict)
print(electro_neutrality_error(ion_molarities_dict, charges_dict, c_Na, c_Cl))
# Out:
# ##### Benchmark pH
# C_a: 0.01 M
#  3.3871  2.0000  2.0000  3.3871  3.3690  3.3780
# end
#
# {'Acetic acid': 0.01}
#
# calc ion molarities
# {'H': array([0.00239883]), 'OH': array([4.16869383e-12]), 'Acetic acid': array([0.00011096])}
# 0.00228787466952717
# 0.001254895584255905
#
# calc ion molarities
# {'H': array([0.0001]), 'OH': array([1.e-10]), 'Acetic acid': array([0.00149217])}
# -0.0013921715590912663
# calc ion molarities
# {'H': array([0.00041687]), 'OH': array([2.39883292e-11]), 'Acetic acid': array([0.00040374])}
# 1.312915653065976e-05
#
# calc ion molarities
# {'H': array([0.00041011]), 'OH': array([2.43837221e-11]), 'Acetic acid': array([0.00041012])}
# -1.2377668000415013e-08

# %%
def bisect(f, a, b, eps=1e-6, maxiter=15, m = 1, verbose = False):
    if f(a)*f(b) >= 0:
        print("Error func")
        return
    i = 0
    while (abs(a-b) > eps and (i < maxiter)):
        zero = (b + a) / 2
        if f(zero)*f(b) < 0:
            a = zero
        else:
            b = zero
        i += 1
    return zero

def calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, ion_strength, c_Na, c_Cl, correct_for_IS=False):

    eps = 1e-8
    i = 0
    error = 1
    pH_low = pH_low
    pH_high = pH_high
    while(abs(error) > eps and i < 100):
        pH = (pH_low + pH_high) / 2
        ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, pH, ion_strength, correct_for_IS=correct_for_IS)
        error = electro_neutrality_error(ion_molarities_dict, charges_dict, c_Na, c_Cl)
        if error > 0:
            pH_low = pH
        else:
            pH_high = pH
        #print("i: {} pH {:.4f} error: {:.4f}".format(i, pH, error))
        i += 1
    return pH
    
def calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, IS_low, IS_high, pH, c_Na, c_Cl, correct_for_IS = True):
    eps = 1e-8
    i = 0
    error = 1
    while(abs(error) > eps and i < 100):
        IS = (IS_low + IS_high) / 2
        ion_molarities_dict = calculate_molarities(molarities_dict, pKa_dict, charges_dict, pH, IS, correct_for_IS=correct_for_IS)
        error = IS - ion_strength(ion_molarities_dict, charges_dict, c_Na, c_Cl)
        if error < 0:
            IS_low = IS 
        else:
            IS_high = IS
        #print("i: {} IS {:.4f} error: {:.4f}".format(i, IS, error))
        i += 1
    return IS

def calculate_pH_IS(molarities_dict, c_Na, c_Cl, initial_pH, pKa_dict, charges_dict, verbose=True):
    IS_min = 0.00001
    IS_max = 5.5
    pH_min = 0.0
    pH_max = 14.0
    error = 1e-5
    
    # TODO some smart guess of initial_pH
    IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, IS_min, IS_max, initial_pH, c_Na, c_Cl, True)
    pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_min, pH_max, IS, c_Na, c_Cl, True)
    if verbose:
        print(f"Initial values, pH: {pH:8.5f} IS: {IS:8.5f}")
    
    iteration = 1
    previous_pH = initial_pH
    while(abs(pH - previous_pH) > error and iteration < 1000):
        IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, IS_min, IS_max, pH, c_Na, c_Cl, True)
        previous_pH = pH
        pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_min, pH_max, IS, c_Na, c_Cl, True)
        if verbose:
            print(f"step: {iteration} pH: {pH:8.5f} IS: {IS:8.5f}")
            print(f"error: {abs(pH-previous_pH):9.7f}")
        iteration += 1
    return pH, IS

# %%
c_Na = 0.0
c_Cl = 0.0

# molarities are in mol/L
molarities_dict = {
    "Acetic acid" : 0.1,
    "Citric acid" : 0.1,
    "Phosphoric acid" : 0.3,
}
#%timeit pH, IS = calculate_pH_IS(molarities_dict, c_Na, c_Cl, 1, pKa_dict, charges_dict, verbose =False)
pH, IS = calculate_pH_IS(molarities_dict, c_Na, c_Cl, 1, pKa_dict, charges_dict, verbose =False)
print("result: ", pH, IS)
# Out:
# result:  1.1537572667002678 0.07018900328360497

# %%
c_Na = 1.2
c_Cl = 1.2

# molarities are in mol/L
molarities_dict = {
    "Acetic acid" : 0.1,
    "Citric acid" : 0.1,
    "Phosphoric acid" : 0.3,
}

pH_low = 0
pH_high = 14
print(molarities_dict)
for IS in [1, 0.1, 0.01, 0.001, 0.0001, 0.000010]:
    calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)

pH = 5
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
IS = calculate_ion_strength_bisect(molarities_dict, pKa_dict, charges_dict, 0.00001, 5.5, pH, c_Na, c_Cl, True)
pH = calculate_pH_bisect(molarities_dict, pKa_dict, charges_dict, pH_low, pH_high, IS, c_Na, c_Cl, True)
print("pH: {:8.5f} IS: {:8.5f}".format(pH, IS))
# Out:
# {'Acetic acid': 0.1, 'Citric acid': 0.1, 'Phosphoric acid': 0.3}
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.09972242]), 'Citric acid': array([1.62324720e-05, 2.41871481e-02, 8.35188803e-01]), 'Phosphoric acid': array([1.70456987e-01, 4.44032551e-01, 8.39875299e-06])}
# i: 0 pH 7.0000 error: -3.7122
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.01020161]), 'Citric acid': array([0.29139535, 0.13730382, 0.00149928]), 'Phosphoric acid': array([6.00988379e-01, 4.95069390e-04, 2.96118864e-12])}
# i: 1 pH 3.5000 error: -1.1824
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00020162]), 'Citric acid': array([3.31372677e-02, 2.77662159e-04, 5.39158797e-08]), 'Phosphoric acid': array([2.77065730e-01, 4.05866131e-06, 4.31700759e-16])}
# i: 2 pH 1.7500 error: -0.2932
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([2.69328936e-05]), 'Citric acid': array([4.74523243e-03, 5.30221690e-06, 1.37295875e-10]), 'Phosphoric acid': array([6.06450360e-02, 1.18466418e-07, 1.68033262e-18])}
# i: 3 pH 0.8750 error: 0.0679
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([7.3719049e-05]), 'Citric acid': array([1.27433754e-02, 3.89928049e-05, 2.76493214e-09]), 'Phosphoric acid': array([1.41751745e-01, 7.58277929e-07, 2.94529239e-17])}
# i: 4 pH 1.3125 error: -0.1060
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.08058422]), 'OH': array([1.24093776e-13]), 'Acetic acid': array([4.45611541e-05]), 'Citric acid': array([7.79468158e-03, 1.44128006e-05, 6.17587331e-10]), 'Phosphoric acid': array([9.42646497e-02, 3.04718525e-07, 7.15235164e-18])}
# i: 5 pH 1.0938 error: -0.0215
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.10366329]), 'OH': array([9.6466162e-14]), 'Acetic acid': array([3.46437199e-05]), 'Citric acid': array([6.08451948e-03, 8.74583513e-06, 2.91324015e-10]), 'Phosphoric acid': array([7.58691699e-02, 1.90651547e-07, 3.47868683e-18])}
# i: 6 pH 0.9844 error: 0.0217
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09139817]), 'OH': array([1.09411381e-13]), 'Acetic acid': array([3.92908866e-05]), 'Citric acid': array([6.88760404e-03, 1.12287309e-05, 4.24221986e-10]), 'Phosphoric acid': array([8.46479068e-02, 2.41256333e-07, 4.99276613e-18])}
# i: 7 pH 1.0391 error: -0.0002
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09733774]), 'OH': array([1.02735077e-13]), 'Acetic acid': array([3.68942334e-05]), 'Citric acid': array([6.47381597e-03, 9.91012424e-06, 3.51558700e-10]), 'Phosphoric acid': array([8.01564412e-02, 2.14514759e-07, 4.16846277e-18])}
# i: 8 pH 1.0117 error: 0.0107
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09432121]), 'OH': array([1.0602069e-13]), 'Acetic acid': array([3.80737138e-05]), 'Citric acid': array([6.67755759e-03, 1.05489265e-05, 3.86188104e-10]), 'Phosphoric acid': array([8.23763049e-02, 2.27506041e-07, 4.56229703e-18])}
# i: 9 pH 1.0254 error: 0.0052
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09284819]), 'OH': array([1.07702693e-13]), 'Acetic acid': array([3.86775143e-05]), 'Citric acid': array([6.78178106e-03, 1.08835438e-05, 4.04759351e-10]), 'Phosphoric acid': array([8.35055965e-02, 2.34283738e-07, 4.77275023e-18])}
# i: 10 pH 1.0322 error: 0.0025
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09212033]), 'OH': array([1.08553675e-13]), 'Acetic acid': array([3.89829946e-05]), 'Citric acid': array([6.83449114e-03, 1.10547956e-05, 4.14376624e-10]), 'Phosphoric acid': array([8.40751191e-02, 2.37745345e-07, 4.88153665e-18])}
# i: 11 pH 1.0356 error: 0.0011
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09175854]), 'OH': array([1.08981684e-13]), 'Acetic acid': array([3.91366379e-05]), 'Citric acid': array([6.86099706e-03, 1.11414252e-05, 4.19270459e-10]), 'Phosphoric acid': array([8.43611042e-02, 2.39494625e-07, 4.93684267e-18])}
# i: 12 pH 1.0374 error: 0.0005
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09157818]), 'OH': array([1.09196321e-13]), 'Acetic acid': array([3.92136864e-05]), 'Citric acid': array([6.87428789e-03, 1.11849932e-05, 4.21738969e-10]), 'Phosphoric acid': array([8.45044032e-02, 2.40373920e-07, 4.96472680e-18])}
# i: 13 pH 1.0382 error: 0.0001
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09148813]), 'OH': array([1.09303798e-13]), 'Acetic acid': array([3.92522675e-05]), 'Citric acid': array([6.88094280e-03, 1.12068408e-05, 4.22978658e-10]), 'Phosphoric acid': array([8.45761294e-02, 2.40814737e-07, 4.97872701e-18])}
# i: 14 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09153314]), 'OH': array([1.09250047e-13]), 'Acetic acid': array([3.92329722e-05]), 'Citric acid': array([6.87761455e-03, 1.11959117e-05, 4.22358360e-10]), 'Phosphoric acid': array([8.45402599e-02, 2.40594231e-07, 4.97172204e-18])}
# i: 15 pH 1.0384 error: 0.0001
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09151063]), 'OH': array([1.09276919e-13]), 'Acetic acid': array([3.92426187e-05]), 'Citric acid': array([6.87927848e-03, 1.12013749e-05, 4.22668395e-10]), 'Phosphoric acid': array([8.45581931e-02, 2.40704459e-07, 4.97522331e-18])}
# i: 16 pH 1.0385 error: 0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09149938]), 'OH': array([1.09290358e-13]), 'Acetic acid': array([3.92474428e-05]), 'Citric acid': array([6.88011059e-03, 1.12041075e-05, 4.22823499e-10]), 'Phosphoric acid': array([8.45671608e-02, 2.40759592e-07, 4.97697486e-18])}
# i: 17 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09150501]), 'OH': array([1.09283638e-13]), 'Acetic acid': array([3.92450307e-05]), 'Citric acid': array([6.87969452e-03, 1.12027411e-05, 4.22745940e-10]), 'Phosphoric acid': array([8.45626769e-02, 2.40732024e-07, 4.97609901e-18])}
# i: 18 pH 1.0386 error: 0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09150219]), 'OH': array([1.09286998e-13]), 'Acetic acid': array([3.92462367e-05]), 'Citric acid': array([6.87990255e-03, 1.12034243e-05, 4.22784717e-10]), 'Phosphoric acid': array([8.45649188e-02, 2.40745808e-07, 4.97653691e-18])}
# i: 19 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.0915036]), 'OH': array([1.09285318e-13]), 'Acetic acid': array([3.92456337e-05]), 'Citric acid': array([6.87979854e-03, 1.12030827e-05, 4.22765328e-10]), 'Phosphoric acid': array([8.45637978e-02, 2.40738916e-07, 4.97631796e-18])}
# i: 20 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.0915043]), 'OH': array([1.09284478e-13]), 'Acetic acid': array([3.92453322e-05]), 'Citric acid': array([6.87974653e-03, 1.12029119e-05, 4.22755634e-10]), 'Phosphoric acid': array([8.45632373e-02, 2.40735470e-07, 4.97620848e-18])}
# i: 21 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09150465]), 'OH': array([1.09284058e-13]), 'Acetic acid': array([3.92451814e-05]), 'Citric acid': array([6.87972053e-03, 1.12028265e-05, 4.22750787e-10]), 'Phosphoric acid': array([8.45629571e-02, 2.40733747e-07, 4.97615374e-18])}
# i: 22 pH 1.0386 error: -0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09150483]), 'OH': array([1.09283848e-13]), 'Acetic acid': array([3.9245106e-05]), 'Citric acid': array([6.87970752e-03, 1.12027838e-05, 4.22748363e-10]), 'Phosphoric acid': array([8.45628170e-02, 2.40732886e-07, 4.97612638e-18])}
# i: 23 pH 1.0386 error: 0.0000
# calc ion molarities
# 4.4446
# 2.8166
# 4.1382
# 5.4618
# 1.8356
# 6.5842
# 11.7232
# {'H': array([0.09150474]), 'OH': array([1.09283953e-13]), 'Acetic acid': array([3.92451437e-05]), 'Citric acid': array([6.87971403e-03, 1.12028052e-05, 4.22749575e-10]), 'Phosphoric acid': array([8.45628870e-02, 2.40733316e-07, 4.97614006e-18])}
# i: 24 pH 1.0386 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.09966209]), 'Citric acid': array([2.86819479e-05, 2.36483679e-02, 4.51849393e-01]), 'Phosphoric acid': array([1.83066160e-01, 3.21417677e-01, 4.09761777e-06])}
# i: 0 pH 7.0000 error: -2.3284
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.00853109]), 'Citric acid': array([0.20077453, 0.05234813, 0.0003163 ]), 'Phosphoric acid': array([4.91257502e-01, 2.72753846e-04, 1.09959453e-12])}
# i: 1 pH 3.5000 error: -0.8064
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00016558]), 'Citric acid': array([1.86018973e-02, 8.62481469e-05, 9.26706700e-09]), 'Phosphoric acid': array([2.03140817e-01, 2.00566724e-06, 1.43787313e-16])}
# i: 2 pH 1.7500 error: -0.2043
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([2.21123449e-05]), 'Citric acid': array([2.63106417e-03, 1.62676182e-06, 2.33086167e-11]), 'Phosphoric acid': array([4.16100868e-02, 5.47848287e-08, 5.23747539e-19])}
# i: 3 pH 0.8750 error: 0.0891
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([6.05296116e-05]), 'Citric acid': array([7.09012266e-03, 1.20045609e-05, 4.71019416e-10]), 'Phosphoric acid': array([9.96566275e-02, 3.59308816e-07, 9.40653249e-18])}
# i: 4 pH 1.3125 error: -0.0581
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.08058422]), 'OH': array([1.24093776e-13]), 'Acetic acid': array([3.65865889e-05]), 'Citric acid': array([4.32753906e-03, 4.42775443e-06, 1.04984711e-10]), 'Phosphoric acid': array([6.53287282e-02, 1.42336372e-07, 2.25178840e-18])}
# i: 5 pH 1.0938 error: 0.0109
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.06264335]), 'OH': array([1.59633854e-13]), 'Acetic acid': array([4.70599451e-05]), 'Citric acid': array([5.54260731e-03, 7.29510656e-06, 2.22509814e-10]), 'Phosphoric acid': array([8.10333847e-02, 2.27117535e-07, 4.62207889e-18])}
# i: 6 pH 1.2031 error: -0.0240
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07104974]), 'OH': array([1.40746466e-13]), 'Acetic acid': array([4.14942672e-05]), 'Citric acid': array([4.89819862e-03, 5.68416168e-06, 1.52860914e-10]), 'Phosphoric acid': array([7.28298732e-02, 1.79973574e-07, 3.22929654e-18])}
# i: 7 pH 1.1484 error: -0.0067
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07566695]), 'OH': array([1.32158089e-13]), 'Acetic acid': array([3.89632653e-05]), 'Citric acid': array([4.60418240e-03, 5.01693877e-06, 1.26684967e-10]), 'Phosphoric acid': array([6.89935533e-02, 1.60089906e-07, 2.69723872e-18])}
# i: 8 pH 1.1211 error: 0.0020
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07332201]), 'OH': array([1.36384691e-13]), 'Acetic acid': array([4.02088645e-05]), 'Citric acid': array([4.74895462e-03, 5.34018343e-06, 1.39159971e-10]), 'Phosphoric acid': array([7.08900078e-02, 1.69750998e-07, 2.95147866e-18])}
# i: 9 pH 1.1348 error: -0.0024
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07448526]), 'OH': array([1.34254758e-13]), 'Acetic acid': array([3.95811673e-05]), 'Citric acid': array([4.67601771e-03, 5.17604883e-06, 1.32776306e-10]), 'Phosphoric acid': array([6.99363870e-02, 1.64852132e-07, 2.82153824e-18])}
# i: 10 pH 1.1279 error: -0.0002
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07507378]), 'OH': array([1.33202298e-13]), 'Acetic acid': array([3.92710015e-05]), 'Citric acid': array([4.63996337e-03, 5.09587540e-06, 1.29694945e-10]), 'Phosphoric acid': array([6.94636259e-02, 1.62454167e-07, 2.75869864e-18])}
# i: 11 pH 1.1245 error: 0.0009
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07477894]), 'OH': array([1.33727493e-13]), 'Acetic acid': array([3.94257795e-05]), 'Citric acid': array([4.65795624e-03, 5.13580632e-06, 1.31226598e-10]), 'Phosphoric acid': array([6.96996699e-02, 1.63648908e-07, 2.78994410e-18])}
# i: 12 pH 1.1262 error: 0.0004
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07463195]), 'OH': array([1.33990866e-13]), 'Acetic acid': array([3.9503397e-05]), 'Citric acid': array([4.66697838e-03, 5.15588848e-06, 1.31999182e-10]), 'Phosphoric acid': array([6.98179443e-02, 1.64249456e-07, 2.80569735e-18])}
# i: 13 pH 1.1271 error: 0.0001
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07455857]), 'OH': array([1.34122748e-13]), 'Acetic acid': array([3.95422631e-05]), 'Citric acid': array([4.67149590e-03, 5.16595886e-06, 1.32387175e-10]), 'Phosphoric acid': array([6.98771446e-02, 1.64550527e-07, 2.81360681e-18])}
# i: 14 pH 1.1275 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07459525]), 'OH': array([1.34056791e-13]), 'Acetic acid': array([3.95228253e-05]), 'Citric acid': array([4.66923660e-03, 5.16092122e-06, 1.32193037e-10]), 'Phosphoric acid': array([6.98475392e-02, 1.64399925e-07, 2.80964934e-18])}
# i: 15 pH 1.1273 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07457691]), 'OH': array([1.34089765e-13]), 'Acetic acid': array([3.9532543e-05]), 'Citric acid': array([4.67036612e-03, 5.16343943e-06, 1.32290070e-10]), 'Phosphoric acid': array([6.98623406e-02, 1.64475210e-07, 2.81162739e-18])}
# i: 16 pH 1.1274 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458608]), 'OH': array([1.34073277e-13]), 'Acetic acid': array([3.95276838e-05]), 'Citric acid': array([4.66980133e-03, 5.16218017e-06, 1.32241545e-10]), 'Phosphoric acid': array([6.98549395e-02, 1.64437563e-07, 2.81063819e-18])}
# i: 17 pH 1.1273 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458149]), 'OH': array([1.34081521e-13]), 'Acetic acid': array([3.95301133e-05]), 'Citric acid': array([4.67008371e-03, 5.16280976e-06, 1.32265805e-10]), 'Phosphoric acid': array([6.98586400e-02, 1.64456385e-07, 2.81113275e-18])}
# i: 18 pH 1.1274 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.0745792]), 'OH': array([1.34085643e-13]), 'Acetic acid': array([3.95313281e-05]), 'Citric acid': array([4.67022491e-03, 5.16312459e-06, 1.32277937e-10]), 'Phosphoric acid': array([6.98604903e-02, 1.64465797e-07, 2.81138006e-18])}
# i: 19 pH 1.1274 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458035]), 'OH': array([1.34083582e-13]), 'Acetic acid': array([3.95307207e-05]), 'Citric acid': array([4.67015431e-03, 5.16296717e-06, 1.32271871e-10]), 'Phosphoric acid': array([6.98595651e-02, 1.64461091e-07, 2.81125640e-18])}
# i: 20 pH 1.1274 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07457977]), 'OH': array([1.34084612e-13]), 'Acetic acid': array([3.95310244e-05]), 'Citric acid': array([4.67018961e-03, 5.16304588e-06, 1.32274904e-10]), 'Phosphoric acid': array([6.98600277e-02, 1.64463444e-07, 2.81131823e-18])}
# i: 21 pH 1.1274 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458006]), 'OH': array([1.34084097e-13]), 'Acetic acid': array([3.95308726e-05]), 'Citric acid': array([4.67017196e-03, 5.16300653e-06, 1.32273388e-10]), 'Phosphoric acid': array([6.98597964e-02, 1.64462268e-07, 2.81128731e-18])}
# i: 22 pH 1.1274 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.0745802]), 'OH': array([1.34083839e-13]), 'Acetic acid': array([3.95307966e-05]), 'Citric acid': array([4.67016314e-03, 5.16298685e-06, 1.32272629e-10]), 'Phosphoric acid': array([6.98596808e-02, 1.64461679e-07, 2.81127186e-18])}
# i: 23 pH 1.1274 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458013]), 'OH': array([1.34083968e-13]), 'Acetic acid': array([3.95308346e-05]), 'Citric acid': array([4.67016755e-03, 5.16299669e-06, 1.32273008e-10]), 'Phosphoric acid': array([6.98597386e-02, 1.64461973e-07, 2.81127958e-18])}
# i: 24 pH 1.1274 error: 0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.0745801]), 'OH': array([1.34084033e-13]), 'Acetic acid': array([3.95308536e-05]), 'Citric acid': array([4.67016976e-03, 5.16300161e-06, 1.32273198e-10]), 'Phosphoric acid': array([6.98597675e-02, 1.64462121e-07, 2.81128345e-18])}
# i: 25 pH 1.1274 error: -0.0000
# calc ion molarities
# 4.530269156575532
# 2.9022691565755316
# 4.309538313151062
# 5.718807469726594
# 1.921269156575531
# 6.755538313151062
# 11.894538313151063
# {'H': array([0.07458011]), 'OH': array([1.34084e-13]), 'Acetic acid': array([3.95308441e-05]), 'Citric acid': array([4.67016865e-03, 5.16299915e-06, 1.32273103e-10]), 'Phosphoric acid': array([6.98597530e-02, 1.64462047e-07, 2.81128152e-18])}
# i: 26 pH 1.1274 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.09953973]), 'Citric acid': array([6.75655117e-05, 2.19619311e-02, 1.65430651e-01]), 'Phosphoric acid': array([1.90286021e-01, 1.79626546e-01, 1.23121573e-06])}
# i: 0 pH 7.0000 error: -1.1894
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.00640107]), 'Citric acid': array([1.06477667e-01, 1.09447030e-02, 2.60705045e-05]), 'Phosphoric acid': array([3.56967002e-01, 1.06559386e-04, 2.30969878e-13])}
# i: 1 pH 3.5000 error: -0.4917
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00012147]), 'Citric acid': array([7.46529479e-03, 1.36455931e-05, 5.78013352e-10]), 'Phosphoric acid': array([1.22362753e-01, 6.49550433e-07, 2.50366670e-17])}
# i: 2 pH 1.7500 error: -0.1122
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([1.62147924e-05]), 'Citric acid': array([1.03983508e-03, 2.53460285e-07, 1.43171104e-12]), 'Phosphoric acid': array([2.28750709e-02, 1.61929541e-08, 8.32318833e-20])}
# i: 3 pH 0.8750 error: 0.1094
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([4.4390393e-05]), 'Citric acid': array([2.81402336e-03, 1.87833544e-06, 2.90548480e-11]), 'Phosphoric acid': array([5.65611285e-02, 1.09643200e-07, 1.54328217e-18])}
# i: 4 pH 1.3125 error: -0.0107
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.08058422]), 'OH': array([1.24093776e-13]), 'Acetic acid': array([2.6829667e-05]), 'Citric acid': array([1.71306110e-03, 6.90984506e-07, 6.45897738e-12]), 'Phosphoric acid': array([3.63808864e-02, 4.26173963e-08, 3.62493772e-19])}
# i: 5 pH 1.0938 error: 0.0425
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.06264335]), 'OH': array([1.59633854e-13]), 'Acetic acid': array([3.45109499e-05]), 'Citric acid': array([2.19658324e-03, 1.13977236e-06, 1.37053009e-11]), 'Phosphoric acid': array([4.55181538e-02, 6.85919699e-08, 7.50519381e-19])}
# i: 6 pH 1.2031 error: 0.0149
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05523158]), 'OH': array([1.81055824e-13]), 'Acetic acid': array([3.91403136e-05]), 'Citric acid': array([2.48652738e-03, 1.46336007e-06, 1.99576386e-11]), 'Phosphoric acid': array([5.07877931e-02, 8.68031485e-08, 1.07723787e-18])}
# i: 7 pH 1.2578 error: 0.0019
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05186134]), 'OH': array([1.92821852e-13]), 'Acetic acid': array([4.16828115e-05]), 'Citric acid': array([2.64530177e-03, 1.65797099e-06, 2.40812281e-11]), 'Phosphoric acid': array([5.36099479e-02, 9.75810016e-08, 1.28968948e-18])}
# i: 8 pH 1.2852 error: -0.0044
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05351994]), 'OH': array([1.86846245e-13]), 'Acetic acid': array([4.03915705e-05]), 'Citric acid': array([2.56470731e-03, 1.55764197e-06, 2.19228731e-11]), 'Phosphoric acid': array([5.21829275e-02, 9.20399662e-08, 1.17875748e-18])}
# i: 9 pH 1.2715 error: -0.0013
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05436903]), 'OH': array([1.83928249e-13]), 'Acetic acid': array([3.97610222e-05]), 'Citric acid': array([2.52531994e-03, 1.50976829e-06, 2.09172310e-11]), 'Phosphoric acid': array([5.14813985e-02, 8.93845401e-08, 1.12687173e-18])}
# i: 10 pH 1.2646 error: 0.0003
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05394281]), 'OH': array([1.85381506e-13]), 'Acetic acid': array([4.00750567e-05]), 'Citric acid': array([2.54493873e-03, 1.53351911e-06, 2.14141604e-11]), 'Phosphoric acid': array([5.18311695e-02, 9.07028745e-08, 1.15252696e-18])}
# i: 11 pH 1.2681 error: -0.0005
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.0541555]), 'OH': array([1.84653448e-13]), 'Acetic acid': array([3.99177308e-05]), 'Citric acid': array([2.53511068e-03, 1.52159755e-06, 2.11642400e-11]), 'Phosphoric acid': array([5.16560360e-02, 9.00413783e-08, 1.13962821e-18])}
# i: 12 pH 1.2664 error: -0.0001
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05426216]), 'OH': array([1.84290492e-13]), 'Acetic acid': array([3.98392995e-05]), 'Citric acid': array([2.53021065e-03, 1.51567143e-06, 2.10403737e-11]), 'Phosphoric acid': array([5.15686553e-02, 8.97123789e-08, 1.13323229e-18])}
# i: 13 pH 1.2655 error: 0.0001
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.0542088]), 'OH': array([1.84471881e-13]), 'Acetic acid': array([3.98784959e-05]), 'Citric acid': array([2.53265950e-03, 1.51863161e-06, 2.11022161e-11]), 'Phosphoric acid': array([5.16123302e-02, 8.98767333e-08, 1.13642582e-18])}
# i: 14 pH 1.2659 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05418215]), 'OH': array([1.84562642e-13]), 'Acetic acid': array([3.98981085e-05]), 'Citric acid': array([2.53388480e-03, 1.52011386e-06, 2.11332053e-11]), 'Phosphoric acid': array([5.16341792e-02, 8.99590194e-08, 1.13802591e-18])}
# i: 15 pH 1.2661 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419547]), 'OH': array([1.84517256e-13]), 'Acetic acid': array([3.9888301e-05]), 'Citric acid': array([2.53327208e-03, 1.51937256e-06, 2.11177050e-11]), 'Phosphoric acid': array([5.16232537e-02, 8.99178673e-08, 1.13722558e-18])}
# i: 16 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05420214]), 'OH': array([1.84494567e-13]), 'Acetic acid': array([3.98833981e-05]), 'Citric acid': array([2.53296577e-03, 1.51900204e-06, 2.11099592e-11]), 'Phosphoric acid': array([5.16177917e-02, 8.98972980e-08, 1.13682563e-18])}
# i: 17 pH 1.2660 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419881]), 'OH': array([1.84505911e-13]), 'Acetic acid': array([3.98858495e-05]), 'Citric acid': array([2.53311892e-03, 1.51918729e-06, 2.11138318e-11]), 'Phosphoric acid': array([5.16205226e-02, 8.99075821e-08, 1.13702559e-18])}
# i: 18 pH 1.2660 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419714]), 'OH': array([1.84511583e-13]), 'Acetic acid': array([3.98870752e-05]), 'Citric acid': array([2.53319550e-03, 1.51927992e-06, 2.11157683e-11]), 'Phosphoric acid': array([5.16218882e-02, 8.99127245e-08, 1.13712558e-18])}
# i: 19 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419797]), 'OH': array([1.84508747e-13]), 'Acetic acid': array([3.98864623e-05]), 'Citric acid': array([2.53315721e-03, 1.51923360e-06, 2.11148000e-11]), 'Phosphoric acid': array([5.16212054e-02, 8.99101533e-08, 1.13707558e-18])}
# i: 20 pH 1.2660 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419756]), 'OH': array([1.84510165e-13]), 'Acetic acid': array([3.98867688e-05]), 'Citric acid': array([2.53317635e-03, 1.51925676e-06, 2.11152842e-11]), 'Phosphoric acid': array([5.16215468e-02, 8.99114389e-08, 1.13710058e-18])}
# i: 21 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419776]), 'OH': array([1.84509456e-13]), 'Acetic acid': array([3.98866156e-05]), 'Citric acid': array([2.53316678e-03, 1.51924518e-06, 2.11150421e-11]), 'Phosphoric acid': array([5.16213761e-02, 8.99107961e-08, 1.13708808e-18])}
# i: 22 pH 1.2660 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419766]), 'OH': array([1.84509811e-13]), 'Acetic acid': array([3.98866922e-05]), 'Citric acid': array([2.53317157e-03, 1.51925097e-06, 2.11151631e-11]), 'Phosphoric acid': array([5.16214614e-02, 8.99111175e-08, 1.13709433e-18])}
# i: 23 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419771]), 'OH': array([1.84509634e-13]), 'Acetic acid': array([3.98866539e-05]), 'Citric acid': array([2.53316917e-03, 1.51924808e-06, 2.11151026e-11]), 'Phosphoric acid': array([5.16214188e-02, 8.99109568e-08, 1.13709121e-18])}
# i: 24 pH 1.2660 error: 0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.05419769]), 'OH': array([1.84509722e-13]), 'Acetic acid': array([3.9886673e-05]), 'Citric acid': array([2.53317037e-03, 1.51924952e-06, 2.11151329e-11]), 'Phosphoric acid': array([5.16214401e-02, 8.99110371e-08, 1.13709277e-18])}
# i: 25 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.665018181818182
# 3.037018181818182
# 4.579036363636364
# 6.123054545454545
# 2.0560181818181817
# 7.025036363636364
# 12.164036363636363
# {'H': array([0.0541977]), 'OH': array([1.84509678e-13]), 'Acetic acid': array([3.98866634e-05]), 'Citric acid': array([2.53316977e-03, 1.51924880e-06, 2.11151177e-11]), 'Phosphoric acid': array([5.16214294e-02, 8.99109969e-08, 1.13709199e-18])}
# i: 26 pH 1.2660 error: -0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.0994721]), 'Citric acid': array([9.63266828e-05, 2.07111202e-02, 1.03195456e-01]), 'Phosphoric acid': array([1.87753742e-01, 1.34552960e-01, 7.00160996e-07])}
# i: 0 pH 7.0000 error: -0.9074
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.00562362]), 'Citric acid': array([7.91342521e-02, 5.38048577e-03, 8.47770835e-06]), 'Phosphoric acid': array([3.09461956e-01, 7.01313054e-05, 1.15402862e-13])}
# i: 1 pH 3.5000 error: -0.4048
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00010585]), 'Citric acid': array([4.96960924e-03, 6.00868209e-06, 1.68358951e-10]), 'Phosphoric acid': array([9.70249871e-02, 3.91010347e-07, 1.14417619e-17])}
# i: 2 pH 1.7500 error: -0.0843
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([1.41283344e-05]), 'Citric acid': array([6.88428132e-04, 1.10998112e-07, 4.14736806e-13]), 'Phosphoric acid': array([1.75054604e-02, 9.40758592e-09, 3.67098703e-20])}
# i: 3 pH 0.8750 error: 0.1151
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([3.86798082e-05]), 'Citric acid': array([1.86584854e-03, 8.23821972e-07, 8.42927758e-12]), 'Phosphoric acid': array([4.38016281e-02, 6.44606841e-08, 6.88810196e-19])}
# i: 4 pH 1.3125 error: 0.0030
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.02942727]), 'OH': array([3.39820833e-13]), 'Acetic acid': array([6.39918e-05]), 'Citric acid': array([3.05526276e-03, 2.23231538e-06, 3.77974530e-11]), 'Phosphoric acid': array([6.65605027e-02, 1.62095609e-07, 2.86632813e-18])}
# i: 5 pH 1.5312 error: -0.0403
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.03785515]), 'OH': array([2.64164832e-13]), 'Acetic acid': array([4.97520756e-05]), 'Citric acid': array([2.38915074e-03, 1.35698653e-06, 1.78610720e-11]), 'Phosphoric acid': array([5.42353734e-02, 1.02674428e-07, 1.41137346e-18])}
# i: 6 pH 1.4219 error: -0.0188
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.0429351]), 'OH': array([2.32909659e-13]), 'Acetic acid': array([4.38681449e-05]), 'Citric acid': array([2.11165029e-03, 1.05746617e-06, 1.22718762e-11]), 'Phosphoric acid': array([4.87897842e-02, 8.14368663e-08, 9.86991040e-19])}
# i: 7 pH 1.3672 error: -0.0080
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04572527]), 'OH': array([2.18697466e-13]), 'Acetic acid': array([4.11924046e-05]), 'Citric acid': array([1.98501489e-03, 9.33392925e-07, 1.01710371e-11]), 'Phosphoric acid': array([4.62397377e-02, 7.24709190e-08, 8.24730726e-19])}
# i: 8 pH 1.3398 error: -0.0025
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04718763]), 'OH': array([2.11919966e-13]), 'Acetic acid': array([3.99163493e-05]), 'Citric acid': array([1.92452525e-03, 8.76904850e-07, 9.25936772e-12]), 'Phosphoric acid': array([4.50068546e-02, 6.83526244e-08, 7.53757637e-19])}
# i: 9 pH 1.3262 error: 0.0002
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04645069]), 'OH': array([2.15282046e-13]), 'Acetic acid': array([4.05493598e-05]), 'Citric acid': array([1.95454011e-03, 9.04709989e-07, 9.70452275e-12]), 'Phosphoric acid': array([4.56198181e-02, 7.03827154e-08, 7.88457861e-19])}
# i: 10 pH 1.3330 error: -0.0012
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04681771]), 'OH': array([2.13594391e-13]), 'Acetic acid': array([4.023161e-05]), 'Citric acid': array([1.93947561e-03, 8.90699383e-07, 9.47933736e-12]), 'Phosphoric acid': array([4.53124694e-02, 6.93605026e-08, 7.70915418e-19])}
# i: 11 pH 1.3296 error: -0.0005
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.0470023]), 'OH': array([2.12755531e-13]), 'Acetic acid': array([4.00736698e-05]), 'Citric acid': array([1.93198621e-03, 8.83775315e-07, 9.36870817e-12]), 'Phosphoric acid': array([4.51594456e-02, 6.88547836e-08, 7.62288966e-19])}
# i: 12 pH 1.3279 error: -0.0001
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04709487]), 'OH': array([2.12337337e-13]), 'Acetic acid': array([3.99949322e-05]), 'Citric acid': array([1.92825218e-03, 8.80333408e-07, 9.31387780e-12]), 'Phosphoric acid': array([4.50830961e-02, 6.86032605e-08, 7.58011476e-19])}
# i: 13 pH 1.3270 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04704857]), 'OH': array([2.12546331e-13]), 'Acetic acid': array([4.00342816e-05]), 'Citric acid': array([1.93011831e-03, 8.82052690e-07, 9.34125283e-12]), 'Phosphoric acid': array([4.51212573e-02, 6.87289110e-08, 7.60147257e-19])}
# i: 14 pH 1.3275 error: -0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707171]), 'OH': array([2.12441809e-13]), 'Acetic acid': array([4.00146021e-05]), 'Citric acid': array([1.92918502e-03, 8.81192632e-07, 9.32755529e-12]), 'Phosphoric acid': array([4.51021733e-02, 6.86660580e-08, 7.59078626e-19])}
# i: 15 pH 1.3272 error: -0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04708329]), 'OH': array([2.12389567e-13]), 'Acetic acid': array([4.00047659e-05]), 'Citric acid': array([1.92871855e-03, 8.80762916e-07, 9.32071404e-12]), 'Phosphoric acid': array([4.50926339e-02, 6.86346524e-08, 7.58544866e-19])}
# i: 16 pH 1.3271 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.0470775]), 'OH': array([2.12415686e-13]), 'Acetic acid': array([4.00096837e-05]), 'Citric acid': array([1.92895177e-03, 8.80977748e-07, 9.32413404e-12]), 'Phosphoric acid': array([4.50974034e-02, 6.86503535e-08, 7.58811700e-19])}
# i: 17 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707461]), 'OH': array([2.12428747e-13]), 'Acetic acid': array([4.00121428e-05]), 'Citric acid': array([1.92906840e-03, 8.81085183e-07, 9.32584451e-12]), 'Phosphoric acid': array([4.50997883e-02, 6.86582053e-08, 7.58945152e-19])}
# i: 18 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707316]), 'OH': array([2.12435278e-13]), 'Acetic acid': array([4.00133724e-05]), 'Citric acid': array([1.92912671e-03, 8.81138906e-07, 9.32669986e-12]), 'Phosphoric acid': array([4.51009808e-02, 6.86621316e-08, 7.59011886e-19])}
# i: 19 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707244]), 'OH': array([2.12438543e-13]), 'Acetic acid': array([4.00139873e-05]), 'Citric acid': array([1.92915587e-03, 8.81165768e-07, 9.32712756e-12]), 'Phosphoric acid': array([4.51015771e-02, 6.86640948e-08, 7.59045255e-19])}
# i: 20 pH 1.3272 error: -0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.0470728]), 'OH': array([2.1243691e-13]), 'Acetic acid': array([4.00136798e-05]), 'Citric acid': array([1.92914129e-03, 8.81152337e-07, 9.32691371e-12]), 'Phosphoric acid': array([4.51012789e-02, 6.86631132e-08, 7.59028571e-19])}
# i: 21 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707262]), 'OH': array([2.12437727e-13]), 'Acetic acid': array([4.00138335e-05]), 'Citric acid': array([1.92914858e-03, 8.81159053e-07, 9.32702063e-12]), 'Phosphoric acid': array([4.51014280e-02, 6.86636040e-08, 7.59036913e-19])}
# i: 22 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707253]), 'OH': array([2.12438135e-13]), 'Acetic acid': array([4.00139104e-05]), 'Citric acid': array([1.92915222e-03, 8.81162410e-07, 9.32707410e-12]), 'Phosphoric acid': array([4.51015025e-02, 6.86638494e-08, 7.59041084e-19])}
# i: 23 pH 1.3272 error: -0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707257]), 'OH': array([2.12437931e-13]), 'Acetic acid': array([4.0013872e-05]), 'Citric acid': array([1.92915040e-03, 8.81160731e-07, 9.32704737e-12]), 'Phosphoric acid': array([4.51014653e-02, 6.86637267e-08, 7.59038999e-19])}
# i: 24 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.724847671763562
# 3.0968476717635616
# 4.698695343527123
# 6.302543015290684
# 2.1158476717635613
# 7.144695343527123
# 12.283695343527123
# {'H': array([0.04707255]), 'OH': array([2.12438033e-13]), 'Acetic acid': array([4.00138912e-05]), 'Citric acid': array([1.92915131e-03, 8.81161571e-07, 9.32706073e-12]), 'Phosphoric acid': array([4.51014839e-02, 6.86637880e-08, 7.59040041e-19])}
# i: 25 pH 1.3272 error: 0.0000
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.09944604]), 'Citric acid': array([0.00010854, 0.02017915, 0.0869407 ]), 'Phosphoric acid': array([1.86046446e-01, 1.21013785e-01, 5.71542210e-07])}
# i: 0 pH 7.0000 error: -0.8288
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.00537189]), 'Citric acid': array([7.11535290e-02, 4.18327719e-03, 5.69950108e-06]), 'Phosphoric acid': array([2.94249909e-01, 6.05243038e-05, 9.03947625e-14])}
# i: 1 pH 3.5000 error: -0.3790
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00010085]), 'Citric acid': array([4.30599689e-03, 4.50187995e-06, 1.09072209e-10]), 'Phosphoric acid': array([8.93349162e-02, 3.26764373e-07, 8.67856989e-18])}
# i: 2 pH 1.7500 error: -0.0760
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([1.34600996e-05]), 'Citric acid': array([5.95448794e-04, 8.30165379e-08, 2.68216083e-13]), 'Phosphoric acid': array([1.59294056e-02, 7.76985716e-09, 2.75186104e-20])}
# i: 3 pH 0.8750 error: 0.1168
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([3.68507781e-05]), 'Citric acid': array([1.61462698e-03, 6.16442258e-07, 5.45396819e-12]), 'Phosphoric acid': array([4.00128948e-02, 5.34457822e-08, 5.18354536e-19])}
# i: 4 pH 1.3125 error: 0.0070
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.02942727]), 'OH': array([3.39820833e-13]), 'Acetic acid': array([6.09665862e-05]), 'Citric acid': array([2.64519054e-03, 1.67119512e-06, 2.44679372e-11]), 'Phosphoric acid': array([6.10082841e-02, 1.34850411e-07, 2.16429144e-18])}
# i: 5 pH 1.5312 error: -0.0343
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.03785515]), 'OH': array([2.64164832e-13]), 'Acetic acid': array([4.73997258e-05]), 'Citric acid': array([2.06791576e-03, 1.01561251e-06, 1.15590792e-11]), 'Phosphoric acid': array([4.96206237e-02, 8.52610515e-08, 1.06374896e-18])}
# i: 6 pH 1.4219 error: -0.0139
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.0429351]), 'OH': array([2.32909659e-13]), 'Acetic acid': array([4.17938795e-05]), 'Citric acid': array([1.82751820e-03, 7.91351459e-07, 7.94103492e-12]), 'Phosphoric acid': array([4.46024521e-02, 6.75708996e-08, 7.43294067e-19])}
# i: 7 pH 1.3672 error: -0.0035
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.04572527]), 'OH': array([2.18697466e-13]), 'Acetic acid': array([3.92446095e-05]), 'Citric acid': array([1.71783270e-03, 6.98465267e-07, 6.58125567e-12]), 'Phosphoric acid': array([4.22553321e-02, 6.01088936e-08, 6.20863244e-19])}
# i: 8 pH 1.3398 error: 0.0017
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.04430823]), 'OH': array([2.25691719e-13]), 'Acetic acid': array([4.04991992e-05]), 'Citric acid': array([1.77184151e-03, 7.43465286e-07, 7.22930451e-12]), 'Phosphoric acid': array([4.34156446e-02, 6.37346116e-08, 6.79366979e-19])}
# i: 9 pH 1.3535 error: -0.0009
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.04501117]), 'OH': array([2.2216707e-13]), 'Acetic acid': array([3.98669715e-05]), 'Citric acid': array([1.74463167e-03, 7.20615563e-07, 6.89768763e-12]), 'Phosphoric acid': array([4.28321963e-02, 6.18961301e-08, 6.49466343e-19])}
# i: 10 pH 1.3467 error: 0.0004
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.04465832]), 'OH': array([2.2392246e-13]), 'Acetic acid': array([4.01818424e-05]), 'Citric acid': array([1.75818485e-03, 7.31951641e-07, 7.06155332e-12]), 'Phosphoric acid': array([4.31230949e-02, 6.28088792e-08, 6.64250921e-19])}
# i: 11 pH 1.3501 error: -0.0003
# calc ion molarities
# 4.745893267326733
# 3.1178932673267328
# 4.7407865346534654
# 6.365679801980198
# 2.1368932673267325
# 7.186786534653465
# 12.325786534653465
# {'H': array([0.0448344]), 'OH': array([2.23043038e-13]), 'Acetic acid': array([4.00240975e-05]), 'Citric acid': array([1.75139537e-03, 7.26261577e-07, 6.97914045e-12]), 'Phosphoric acid': array([4.29774395e-02, 6.23508926e-08, 6.56817646e-19])}
# ...
# 1.8208650685624845
# 6.554730137124969
# 11.69373013712497
# i: 2 IS 0.6875 error: -0.6071
# calc ion molarities
# 4.446916538807205
# 2.818916538807205
# 4.1428330776144096
# 5.468749616421614
# 1.8379165388072045
# 6.588833077614409
# 11.72783307761441
# i: 3 IS 1.0313 error: -0.2595
# calc ion molarities
# 4.461600242033408
# 2.833600242033408
# 4.172200484066816
# 5.512800726100224
# 1.8526002420334078
# 6.618200484066816
# 11.757200484066816
# i: 4 IS 1.2031 error: -0.0846
# calc ion molarities
# 4.469993749120126
# 2.841993749120125
# 4.18898749824025
# 5.537981247360375
# 1.8609937491201247
# 6.63498749824025
# 11.77398749824025
# i: 5 IS 1.2891 error: 0.0029
# calc ion molarities
# 4.4657190918957665
# 2.837719091895767
# 4.180438183791534
# 5.5251572756873
# 1.8567190918957663
# 6.626438183791533
# 11.765438183791533
# i: 6 IS 1.2461 error: -0.0409
# calc ion molarities
# 4.46783757701627
# 2.839837577016269
# 4.184675154032538
# 5.5315127310488075
# 1.8588375770162688
# 6.630675154032538
# 11.769675154032539
# i: 7 IS 1.2676 error: -0.0190
# calc ion molarities
# 4.468911027939314
# 2.840911027939314
# 4.186822055878627
# 5.534733083817941
# 1.8599110279393136
# 6.632822055878627
# 11.771822055878628
# i: 8 IS 1.2783 error: -0.0080
# calc ion molarities
# 4.469451239018519
# 2.8414512390185194
# 4.187902478037039
# 5.536353717055557
# 1.8604512390185188
# 6.633902478037038
# 11.772902478037038
# i: 9 IS 1.2837 error: -0.0025
# calc ion molarities
# 4.46972220783838
# 2.84172220783838
# 4.188444415676761
# 5.537166623515141
# 1.86072220783838
# 6.634444415676761
# 11.77344441567676
# i: 10 IS 1.2864 error: 0.0002
# calc ion molarities
# 4.469586651727888
# 2.841586651727888
# 4.188173303455776
# 5.536759955183664
# 1.8605866517278877
# 6.634173303455776
# 11.773173303455776
# i: 11 IS 1.2850 error: -0.0012
# calc ion molarities
# 4.46965441187588
# 2.84165441187588
# 4.18830882375176
# 5.53696323562764
# 1.8606544118758799
# 6.63430882375176
# 11.77330882375176
# i: 12 IS 1.2857 error: -0.0005
# calc ion molarities
# 4.46968830538255
# 2.84168830538255
# 4.1883766107651
# 5.537064916147649
# 1.8606883053825494
# 6.634376610765099
# 11.7733766107651
# i: 13 IS 1.2860 error: -0.0001
# calc ion molarities
# 4.469705255492099
# 2.8417052554920987
# 4.188410510984197
# 5.537115766476296
# 1.8607052554920986
# 6.634410510984197
# 11.773410510984197
# i: 14 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.469696780157698
# 2.841696780157698
# 4.1883935603153954
# 5.537090340473093
# 1.8606967801576977
# 6.634393560315395
# 11.773393560315396
# i: 15 IS 1.2861 error: -0.0000
# calc ion molarities
# 4.469701017754996
# 2.841701017754996
# 4.188402035509992
# 5.537103053264988
# 1.8607010177549959
# 6.634402035509992
# 11.773402035509992
# i: 16 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469703136606073
# 2.8417031366060725
# 4.188406273212145
# 5.537109409818218
# 1.8607031366060722
# 6.634406273212145
# 11.773406273212146
# i: 17 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.469702077176166
# 2.8417020771761656
# 4.188404154352331
# 5.5371062315284965
# 1.8607020771761653
# 6.634404154352331
# 11.773404154352331
# i: 18 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.4697015474644886
# 2.8417015474644884
# 4.188403094928977
# 5.537104642393466
# 1.8607015474644883
# 6.6344030949289765
# 11.773403094928977
# i: 19 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.46970128260947
# 2.8417012826094696
# 4.188402565218939
# 5.5371038478284085
# 1.860701282609469
# 6.634402565218939
# 11.77340256521894
# i: 20 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701415036911
# 2.8417014150369106
# 4.188402830073821
# 5.537104245110732
# 1.8607014150369103
# 6.634402830073821
# 11.773402830073822
# i: 21 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701481250683
# 2.8417014812506824
# 4.188402962501365
# 5.537104443752047
# 1.8607014812506821
# 6.6344029625013645
# 11.773402962501365
# i: 22 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.469701448143793
# 2.8417014481437923
# 4.1884028962875846
# 5.537104344431377
# 1.860701448143792
# 6.634402896287584
# 11.773402896287585
# i: 23 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701464697237
# 2.8417014646972363
# 4.1884029293944725
# 5.537104394091709
# 1.8607014646972362
# 6.634402929394472
# 11.773402929394473
# i: 24 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701472973959
# 2.841701472973959
# 4.188402945947918
# 5.537104418921878
# 1.860701472973959
# 6.634402945947918
# 11.773402945947918
# i: 25 IS 1.2862 error: 0.0000
# calc ion molarities
# 4.469701468835598
# 2.841701468835598
# 4.188402937671196
# 5.537104406506793
# 1.8607014688355976
# 6.6344029376711955
# 11.773402937671195
# i: 26 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# i: 27 IS 1.2862 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([1.e-07]), 'OH': array([1.e-07]), 'Acetic acid': array([0.09970595]), 'Citric acid': array([1.92032801e-05, 2.40586362e-02, 6.98500292e-01]), 'Phosphoric acid': array([1.74662396e-01, 4.05318543e-01, 6.82957267e-06])}
# i: 0 pH 7.0000 error: -3.2287
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.00031623]), 'OH': array([3.16227766e-11]), 'Acetic acid': array([0.00968417]), 'Citric acid': array([0.26202505, 0.10380981, 0.00095309]), 'Phosphoric acid': array([5.66572851e-01, 4.15769683e-04, 2.21538840e-12])}
# i: 1 pH 3.5000 error: -1.0493
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.01778279]), 'OH': array([5.62341325e-13]), 'Acetic acid': array([0.00019031]), 'Citric acid': array([2.79875782e-02, 1.97179113e-04, 3.21926327e-08]), 'Phosphoric acid': array([2.53232164e-01, 3.30457737e-06, 3.13121568e-16])}
# i: 2 pH 1.7500 error: -0.2640
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.13335214]), 'OH': array([7.49894209e-14]), 'Acetic acid': array([2.54207356e-05]), 'Citric acid': array([3.99235763e-03, 3.75080965e-06, 8.16621128e-11]), 'Phosphoric acid': array([5.43257915e-02, 9.45372839e-08, 1.19453857e-18])}
# i: 3 pH 0.8750 error: 0.0750
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.04869675]), 'OH': array([2.05352503e-13]), 'Acetic acid': array([6.9581892e-05]), 'Citric acid': array([1.07330864e-02, 2.76134210e-05, 1.64632586e-09]), 'Phosphoric acid': array([1.27934752e-01, 6.09657036e-07, 2.10951515e-17])}
# i: 4 pH 1.3125 error: -0.0901
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08058422]), 'OH': array([1.24093776e-13]), 'Acetic acid': array([4.20596668e-05]), 'Citric acid': array([6.56067428e-03, 1.01998566e-05, 3.67485029e-10]), 'Phosphoric acid': array([8.47039338e-02, 2.43921812e-07, 5.10032319e-18])}
# i: 5 pH 1.0938 error: -0.0107
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.10366329]), 'OH': array([9.6466162e-14]), 'Acetic acid': array([3.26987761e-05]), 'Citric acid': array([5.12007617e-03, 6.18795304e-06, 1.73307595e-10]), 'Phosphoric acid': array([6.80587852e-02, 1.52354839e-07, 2.47644285e-18])}
# i: 6 pH 0.9844 error: 0.0304
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.09139817]), 'OH': array([1.09411381e-13]), 'Acetic acid': array([3.70851415e-05]), 'Citric acid': array([5.79649189e-03, 7.94553820e-06, 2.52395384e-10]), 'Phosphoric acid': array([7.59951887e-02, 1.92950388e-07, 3.55717486e-18])}
# i: 7 pH 1.0391 error: 0.0096
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08582104]), 'OH': array([1.16521549e-13]), 'Acetic acid': array([3.94941912e-05]), 'Citric acid': array([6.16695628e-03, 9.00269852e-06, 3.04561178e-10]), 'Phosphoric acid': array([8.02504496e-02, 2.16995527e-07, 4.26043644e-18])}
# i: 8 pH 1.0664 error: -0.0007
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08856571]), 'OH': array([1.12910512e-13]), 'Acetic acid': array([3.82707228e-05]), 'Citric acid': array([5.97890219e-03, 8.45768315e-06, 2.77256268e-10]), 'Phosphoric acid': array([7.80983507e-02, 2.04631881e-07, 3.89318220e-18])}
# i: 9 pH 1.0527 error: 0.0044
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08718257]), 'OH': array([1.14701821e-13]), 'Acetic acid': array([3.88776464e-05]), 'Citric acid': array([6.07221334e-03, 8.72595405e-06, 2.90588766e-10]), 'Phosphoric acid': array([7.91682436e-02, 2.10726125e-07, 4.07273123e-18])}
# i: 10 pH 1.0596 error: 0.0019
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08649913]), 'OH': array([1.15608105e-13]), 'Acetic acid': array([3.91847067e-05]), 'Citric acid': array([6.11940452e-03, 8.86325066e-06, 2.97493102e-10]), 'Phosphoric acid': array([7.97078026e-02, 2.13838636e-07, 4.16554198e-18])}
# i: 11 pH 1.0630 error: 0.0006
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08615941]), 'OH': array([1.16063928e-13]), 'Acetic acid': array([3.93391447e-05]), 'Citric acid': array([6.14313516e-03, 8.93270360e-06, 3.01006433e-10]), 'Phosphoric acid': array([7.99787395e-02, 2.15411497e-07, 4.21272590e-18])}
# i: 12 pH 1.0647 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.0863291]), 'OH': array([1.15835792e-13]), 'Acetic acid': array([3.92618498e-05]), 'Citric acid': array([6.13125855e-03, 8.89790964e-06, 2.99244621e-10]), 'Phosphoric acid': array([7.98431745e-02, 2.14623675e-07, 4.18906847e-18])}
# i: 13 pH 1.0638 error: 0.0003
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08624422]), 'OH': array([1.15949804e-13]), 'Acetic acid': array([3.93004782e-05]), 'Citric acid': array([6.13719403e-03, 8.91528972e-06, 3.00124236e-10]), 'Phosphoric acid': array([7.99109328e-02, 2.15017238e-07, 4.20088077e-18])}
# i: 14 pH 1.0643 error: 0.0001
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.0862018]), 'OH': array([1.16006852e-13]), 'Acetic acid': array([3.93198067e-05]), 'Citric acid': array([6.14016389e-03, 8.92399243e-06, 3.00565011e-10]), 'Phosphoric acid': array([7.99448301e-02, 2.15214280e-07, 4.20679923e-18])}
# i: 15 pH 1.0645 error: 0.0001
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08618061]), 'OH': array([1.16035387e-13]), 'Acetic acid': array([3.93294745e-05]), 'Citric acid': array([6.14164935e-03, 8.92834696e-06, 3.00785641e-10]), 'Phosphoric acid': array([7.99617833e-02, 2.15312867e-07, 4.20976154e-18])}
# i: 16 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617001]), 'OH': array([1.16049657e-13]), 'Acetic acid': array([3.93343093e-05]), 'Citric acid': array([6.14239221e-03, 8.93052502e-06, 3.00896017e-10]), 'Phosphoric acid': array([7.99702610e-02, 2.15362177e-07, 4.21124346e-18])}
# i: 17 pH 1.0646 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617531]), 'OH': array([1.16042521e-13]), 'Acetic acid': array([3.93318918e-05]), 'Citric acid': array([6.14202077e-03, 8.92943592e-06, 3.00840824e-10]), 'Phosphoric acid': array([7.99660221e-02, 2.15337520e-07, 4.21050244e-18])}
# i: 18 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617266]), 'OH': array([1.16046089e-13]), 'Acetic acid': array([3.93331006e-05]), 'Citric acid': array([6.14220649e-03, 8.92998045e-06, 3.00868419e-10]), 'Phosphoric acid': array([7.99681415e-02, 2.15349848e-07, 4.21087293e-18])}
# i: 19 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617133]), 'OH': array([1.16047873e-13]), 'Acetic acid': array([3.93337049e-05]), 'Citric acid': array([6.14229935e-03, 8.93025273e-06, 3.00882217e-10]), 'Phosphoric acid': array([7.99692013e-02, 2.15356012e-07, 4.21105819e-18])}
# i: 20 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617067]), 'OH': array([1.16048765e-13]), 'Acetic acid': array([3.93340071e-05]), 'Citric acid': array([6.14234578e-03, 8.93038887e-06, 3.00889117e-10]), 'Phosphoric acid': array([7.99697312e-02, 2.15359094e-07, 4.21115083e-18])}
# i: 21 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617034]), 'OH': array([1.16049211e-13]), 'Acetic acid': array([3.93341582e-05]), 'Citric acid': array([6.14236900e-03, 8.93045694e-06, 3.00892567e-10]), 'Phosphoric acid': array([7.99699961e-02, 2.15360635e-07, 4.21119714e-18])}
# i: 22 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617017]), 'OH': array([1.16049434e-13]), 'Acetic acid': array([3.93342338e-05]), 'Citric acid': array([6.14238060e-03, 8.93049098e-06, 3.00894292e-10]), 'Phosphoric acid': array([7.99701286e-02, 2.15361406e-07, 4.21122030e-18])}
# i: 23 pH 1.0646 error: 0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617009]), 'OH': array([1.16049545e-13]), 'Acetic acid': array([3.93342715e-05]), 'Citric acid': array([6.14238641e-03, 8.93050800e-06, 3.00895154e-10]), 'Phosphoric acid': array([7.99701948e-02, 2.15361791e-07, 4.21123188e-18])}
# i: 24 pH 1.0646 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617013]), 'OH': array([1.16049489e-13]), 'Acetic acid': array([3.93342527e-05]), 'Citric acid': array([6.14238351e-03, 8.93049949e-06, 3.00894723e-10]), 'Phosphoric acid': array([7.99701617e-02, 2.15361599e-07, 4.21122609e-18])}
# i: 25 pH 1.0646 error: -0.0000
# calc ion molarities
# 4.469701470904779
# 2.8417014709047788
# 4.188402941809557
# 5.537104412714335
# 1.8607014709047782
# 6.634402941809557
# 11.773402941809557
# {'H': array([0.08617015]), 'OH': array([1.16049462e-13]), 'Acetic acid': array([3.93342432e-05]), 'Citric acid': array([6.14238206e-03, 8.93049523e-06, 3.00894507e-10]), 'Phosphoric acid': array([7.99701451e-02, 2.15361502e-07, 4.21122320e-18])}
# i: 26 pH 1.0646 error: 0.0000
# pH:  1.06464 IS:  1.28618

# %%
3.387
# Out:
# 3.387
